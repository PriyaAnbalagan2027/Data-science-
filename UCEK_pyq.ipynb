# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyaAnbalagan2027/Data-science-/blob/main/UCEK_pyq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.data science and big data:
'''Data science is an evolutionary extension of statistics capable of dealing with the massive amounts of data
produced today. It adds methods from computer science to the repertoire of statistics.
#big data:
Data science and big data are used almost everywhere in both commercial and noncommercial Settings
 Commercial companies in almost every industry use data science and big data to gain insights into
their customers, processes, staff, completion, and products.'''
# Out:
# 'Data science is an evolutionary extension of statistics capable of dealing with the massive amounts of data \nproduced today. It adds methods from computer science to the repertoire of statistics.\n#big data:\nData science and big data are used almost everywhere in both commercial and noncommercial Settings\n Commercial companies in almost every industry use data science and big data to gain insights into \ntheir customers, processes, staff, completion, and products.'

# %%
#2.List an overview of common errors in retrieving data and which cleansing solution to be employed
'''Missing values Error: Incomplete or null data entries.
Cleansing: Imputation by mean, median, or mode; deletion of rows/columns; predictive modeling.
Duplicate Records:Repetition of identical data entries.
Cleansing: Remove huu based on unique identifiers or attributes.
Inconsistent Formatting:Varied formats for the same data (e.g., dates, currencies).
Cleansing: Standardize formats through formatting functions or regex.
Outliers:Data points significantly deviating from the norm.
Cleansing: Trim, winsorize, or transform outliers using statistical methods.
Incorrect Data Types:Mismatch between expected and actual data types.
Cleansing: Convert data types using appropriate functions.'''
# Out:
# 'Missing values Error: Incomplete or null data entries.\nCleansing: Imputation by mean, median, or mode; deletion of rows/columns; predictive modeling.\nDuplicate Records:Repetition of identical data entries.\nCleansing: Remove huu based on unique identifiers or attributes.\nInconsistent Formatting:Varied formats for the same data (e.g., dates, currencies).\nCleansing: Standardize formats through formatting functions or regex.\nOutliers:Data points significantly deviating from the norm.\nCleansing: Trim, winsorize, or transform outliers using statistical methods.\nIncorrect Data Types:Mismatch between expected and actual data types.\nCleansing: Convert data types using appropriate functions.'

# %%
#3.Classify the below list of data into the types:
#a) ethnic groups
#b) age
#c)family size
#d)academic major
#e)sexual preference
#f)IQ score
#g) net worth(dollars)
#h)third place finish
#i) gender
#j)temperature
#brief note on them
'''Data Classification:

#1. **Nominal Data:**
   #- a) Ethnic groups
   # - d) Academic major
   #- e) Sexual preference
   #- h) Third place finish
   #- i) Gender

   *Nominal data* represents categories without inherent order or ranking.

#2. #**Ordinal Data:**
  # - j) Temperature

   #*Ordinal data* has categories with a meaningful order, but the intervals between them may not be consistent.

#3. **Interval Data:**
   #- b) Age
   #- f) IQ score

   # *Interval data* has consistent intervals between values, but lacks a true zero point.

#4. **Ratio Data:**
   #- c) Family size
   #- g) Net worth (dollars)

   #*Ratio data* has a true zero point, and ratios between values are meaningful.'''
# Out:
# 'Data Classification:\n\n#1. **Nominal Data:**\n   #- a) Ethnic groups\n   # - d) Academic major\n   #- e) Sexual preference\n   #- h) Third place finish\n   #- i) Gender\n\n   *Nominal data* represents categories without inherent order or ranking.\n\n#2. #**Ordinal Data:**\n  # - j) Temperature\n\n   #*Ordinal data* has categories with a meaningful order, but the intervals between them may not be consistent.\n\n#3. **Interval Data:**\n   #- b) Age\n   #- f) IQ score\n\n   # *Interval data* has consistent intervals between values, but lacks a true zero point.\n\n#4. **Ratio Data:**\n   #- c) Family size\n   #- g) Net worth (dollars)\n\n   #*Ratio data* has a true zero point, and ratios between values are meaningful.'

# %%
#4.Differentiate discrete and continuous variable
'''discrete variable is a type of statistical variable that can assume only fixed number of distinct values and lacks an inherent order.
Also known as a categorical variable, because it has separate, invisible categories. However no values can exist in-between two categories, i.e. it does not attain all the values within the limits of the variable. So, the number of permitted values that it can suppose is either finite or countably infinite.
continuous variable is one that is defined over an interval of values, meaning that it can suppose any values in between the minimum and maximum value. It can be understood as the function for the interval and for each function, the range for the variable may vary.'''
# Out:
# 'discrete variable is a type of statistical variable that can assume only fixed number of distinct values and lacks an inherent order.\nAlso known as a categorical variable, because it has separate, invisible categories. However no values can exist in-between two categories, i.e. it does not attain all the values within the limits of the variable. So, the number of permitted values that it can suppose is either finite or countably infinite.\ncontinuous variable is one that is defined over an interval of values, meaning that it can suppose any values in between the minimum and maximum value. It can be understood as the function for the interval and for each function, the range for the variable may vary.'

# %%
#5.What is percentail rank and give example?
'''Percentile rank is a measure that indicates the percentage of scores in a dataset that are equal to or below a particular value. It provides a relative position of a specific data point within the entire
 distribution
For example, if a student scores in the 80th percentile on a standardized test, it means that their score is equal to or higher than 80% of the scores in the overall test-taking population. In other words, the student performed better than 80% of the test-takers. Percentile rank is particularly useful in educational assessments and standardized testing to understand how an individual's performance compares to a larger group.'''
# Out:
# "Percentile rank is a measure that indicates the percentage of scores in a dataset that are equal to or below a particular value. It provides a relative position of a specific data point within the entire\n distribution\nFor example, if a student scores in the 80th percentile on a standardized test, it means that their score is equal to or higher than 80% of the scores in the overall test-taking population. In other words, the student performed better than 80% of the test-takers. Percentile rank is particularly useful in educational assessments and standardized testing to understand how an individual's performance compares to a larger group."

# %%
#6.Consider Helen sent 10 greeting cards to her friends and she received back 8 cards, what is the kind of relationship it is? Brief on it
'''The relationship between the number of greeting cards Helen sent (10) and the number she received back (8) represents a one-to-many relationship. In this context, each greeting card sent by Helen corresponds to a unique response, and there can be multiple responses (received cards) for each sent card. This type of relationship is common in scenarios where one entity is related to multiple instances of another entity.'''
# Out:
# 'The relationship between the number of greeting cards Helen sent (10) and the number she received back (8) represents a one-to-many relationship. In this context, each greeting card sent by Helen corresponds to a unique response, and there can be multiple responses (received cards) for each sent card. This type of relationship is common in scenarios where one entity is related to multiple instances of another entity.'

# %%
#7.attributes of numpy array
'''ndim (the number of dimensions),
shape (the size of each dimension)
size (the total size of the array)'''
# Out:
# 'ndim (the number of dimensions),\nshape (the size of each dimension)\nsize (the total size of the array)'

# %%
#8. Create a data frame with key and data pairs as Key-Data pair as A-10, B-20, A-40, C-5, B-10, C-10. Find the sum of each key and display the result as each key group.




import pandas as pd

# Create a dictionary with Key-Data pairs
data = {'Key': ['A', 'B', 'A', 'C', 'B', 'C'],
        'Data': [10, 20, 40, 5, 10, 10]}

# Create a DataFrame
df = pd.DataFrame(data)

# Group by 'Key' and calculate the sum for each group
result = df.groupby('Key')['Data'].sum()

# Display the result
print(result)
#To perform this task, you can use a programming language like Python with the pandas library. Here's a simple example using Python:
# Out:
# Key
# A    50
# B    30
# C    15
# Name: Data, dtype: int64

# %%
#9.A basic errorbar can be created with a single Matplotlib function call.
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k');
# Out:
# <ipython-input-54-d56df258fe2c>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
#10.Show case 3 dimensional drawing   with corresponding python code?
#Creating a 3D drawing typically involves using libraries like Matplotlib in Python. Below is a simple example of a 3D plot using Matplotlib:


import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Generate data points
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# Plot the 3D surface
ax.plot_surface(x, y, z, cmap='viridis')

# Set labels
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

# Show the plot
plt.show()



#This code creates a 3D surface plot of the function `z = sin(sqrt(x^2 + y^2))`. You can modify the function and data points according to your requirements for a different 3D representation.

# %%
#11a.Examine the different facets of data with the challenges in their processing.
'''Facets of Data
• Very large amount of data will generate in big data and data science. These data is various types and main categories of data are as follows:
a) Structured
b) Natural language
c) Graph-based
d) Streaming
e) Unstructured
f) Machine-generated
g) Audio, video and images
Structured Data
Structured data is arranged in rows and column format. It helps for application to retrieve and process data easily. Database management system is used for storing structured data.
The term structured data refers to data that is identifiable because it is organized in a structure. The most common form of structured data or records is a database where specific information is stored based on a methodology of columns and rows.
Structured data is also searchable by data type within content. Structured data is understood by computers and is also efficiently organized for human readers.
An Excel table is an example of structured data.

Unstructured Data
Unstructured data is data that does not follow a specified format. Row and columns are not used for unstructured data. Therefore it is difficult to retrieve required information. Unstructured data has no identifiable structure.
The unstructured data can be in the form of Text: (Documents, email messages, customer feedbacks), audio, video, images. Email is an example of unstructured data.
Even today in most of the organizations more than 80 % of the data are in unstructured form. This carries lots of information. But extracting information from these various sources is a very big challenge.
Natural language
Natural language is a special type of unstructured data; it’s challenging to process because it requires
knowledge of specific data science techniques and linguistics.
The natural language processing community has had success in entity recognition, topic recognition,
summarization, text completion, and sentiment analysis, but models trained in one domain don’t
generalize well to other domains.
Even state-of-the-art techniques aren’t able to decipher the meaning of every piece of text.
Machine-generated data
Machine-generated data is information that’s automatically created by a computer, process,
application, or other machine without human intervention.
Machine-generated data is becoming a major data resource and will continue to do so.
The analysis of machine data relies on highly scalable tools, due to its high volume and speed.
Examples of machine data are web server logs, call detail records, network event logs, and telemetry.
Graph-based or network data
“Graph data” can be a confusing term because any data can be shown in a graph.
Graph or network data is, in short, data that focuses on the relationship or adjacency of objects.
The graph structures use nodes, edges, and properties to represent and store graphical data.
Graph-based data is a natural way to represent social networks, and its structure allows you to
calculate specific metrics such as the influence of a person and the shortest path between two people.
Audio, image, and video
Audio, image, and video are data types that pose specific challenges to a data scientist.
Tasks that are trivial for humans, such as recognizing objects in pictures, turn out to be challenging for
computers.
MLBAM (Major League Baseball Advanced Media) announced in 2014 that they’ll increase video
capture to approximately 7 TB per game for the purpose of live, in-game analytics.
Recently a company called DeepMind succeeded at creating an algorithm that’s capable of learning
how to play video games.
This algorithm takes the video screen as input and learns to interpret everything via a complex process
of deep learning.
Streaming data
The data flows into the system when an event happens instead of being loaded into a data store in a
batch.
Examples are the “What’s trending” on Twitter, live sporting or music events, and the stock market.'''
# Out:
# 'Facets of Data\n• Very large amount of data will generate in big data and data science. These data is various types and main categories of data are as follows:\na) Structured\nb) Natural language\nc) Graph-based\nd) Streaming\ne) Unstructured\nf) Machine-generated\ng) Audio, video and images\nStructured Data\nStructured data is arranged in rows and column format. It helps for application to retrieve and process data easily. Database management system is used for storing structured data.\nThe term structured data refers to data that is identifiable because it is organized in a structure. The most common form of structured data or records is a database where specific information is stored based on a methodology of columns and rows.\nStructured data is also searchable by data type within content. Structured data is understood by computers and is also efficiently organized for human readers.\nAn Excel table is an example of structured data.\n\nUnstructured Data\nUnstructured data is dat
# ...

# %%
#11) b. Explore the various steps associated with data science  and explain any threee steps of it with suitable diagram and exam
'''Streaming data
 The data flows into the system when an event happens instead of being loaded into a data store in a
batch.
 Examples are the “What’s trending” on Twitter, live sporting or music events, and the stock market.
Data Science Process
Overview of the data science process
The typical data science process consists of six steps through which you’ll iterate, as shown in figure
1. The first step of this process is setting a research goal. The main purpose here is making sure all the
stakeholders understand the what, how, and why of the project. In every serious project this will result
in a project charter.
2. The second phase is data retrieval. You want to have data available for analysis, so this step includes
finding suitable data and getting access to the data from the data owner. The result is data in its raw
form, which probably needs polishing and transformation before it becomes usable.
3. Now that you have the raw data, it’s time to prepare it. This includes transforming the data from a raw
form into data that’s directly usable in your models. To achieve this, you’ll detect and correct different
kinds of errors in the data, combine data from different data sources, and transform it. If you have
successfully completed this step, you can progress to data visualization and modeling.
4.The fourth step is data exploration. The goal of this step is to gain a deep understanding of the data.
You’ll look for patterns, correlations, and deviations based on visual and descriptive techniques. The
insights you gain from this phase will enable you to start modeling.
5. Finally, we get to model building (often referred to as “data modeling” throughout this book). It is now
that you attempt to gain the insights or make the predictions stated in your project charter. Now is the
time to bring out the heavy guns, but remember research has taught us that often (but not always) a
combination of simple models tends to outperform one complicated model. If you’ve done this phase
right, you’re almost done.
6. The last step of the data science model is presenting your results and automating the analysis, if
needed. One goal of a project is to change a process and/or make better decisions. You may still need
to convince the business that your findings will indeed change the business process as expected. This
is where you can shine in your influencer role.
A project starts by understanding the what, the why, and the how of your project. The outcome should be a
he last step of the data science model is presenting your results and automating the analysis, if
needed. One goal of a project is to change a process and/or make better decisions. You may still need
to convince the business that your findings will indeed change the business process as expected. This
is where you can shine in your influencer role. The importance of this step is more apparent in projects
on a strategic and tactical level. Certain projects require you to perform the business process over and
over again, so automating the project will save time.'''

# %%
#12.a.Demonstraye the use of different types of variable in data analysis with an example for each
'''TYPES OF VARIABLES
A variable is a characteristic or property that can take on different values.
 The weights can be described not only as quantitative data but also as observations for a quantitative
variable, since the various weights take on different numerical values.
 By the same token, the replies can be described as observations for a qualitative variable, since the
replies to the Facebook profile question take on different values of either Yes or No.
 Given this perspective, any single observation can be described as a constant, since it takes on only
one value.
Discrete and Continuous Variables
Quantitative variables can be further distinguished as discrete or continuous.
A discrete variable consists of isolated numbers separated by gaps.
Discrete variables can only assume specific values that you cannot subdivide. Typically, you count discrete
values, and the results are integers.
Examples
 Counts- such as the number of children in a family. (1, 2, 3, etc., but never 1.5)
 These variables cannot have fractional or decimal values. You can have 20 or 21 cats, but not 20.5
 The number of heads in a sequence of coin tosses.
 The result of rolling a die.
 The number of patients in a hospital.
 The population of a country.
While discrete variables have no decimal places, the average of these values can be fractional. For example,
families can have only a discrete number of children: 1, 2, 3, etc. However, the average number of children
per family can be 2.2.
A continuous variable consists of numbers whose values, at least in theory, have no restrictions.
Continuous variables can assume any numeric value and can be meaningfully split into smaller parts.
Consequently, they have valid fractional and decimal values. In fact, continuous variables have an infinite
number of potential values between any two points. Generally, you measure them using a scale.
Examples of continuous variables include weight, height, length, time, and temperature.
Durations, such as the reaction times of grade school children to a fire alarm; and standardized test scores,
such as those on the Scholastic Aptitude Test (SAT).
Independent and Dependent Variables
Independent Variable
In an experiment, an independent variable is the treatment manipulated by the investigator.
 Independent variables (IVs) are the ones that you include in the model to explain or predict changes in
the dependent variable.
 Independent indicates that they stand alone and other variables in the model do not influence them.
 Independent variables are also known as predictors, factors, treatment variables, explanatory variables,
input variables, x-variables, and right-hand variables—because they appear on the right side of the
equals sign in a regression equation.
 It is a variable that stands alone and isn't changed by the other variables you are trying to measure.
For example, someone's age might be an independent variable. Other factors (such as what they eat, how
much they go to school, how much television they watch)
The impartial creation of distinct groups, which differ only in terms of the independent variable, has a most
desirable consequence. Once the data have been collected, any difference between the groups can be
interpreted as being caused by the independent variable.
Dependent Variable
When a variable is believed to have been influenced by the independent variable, it is called a dependent
variable. In an experimental setting, the dependent variable is measured, counted, or recorded by the
investigator.
 The dependent variable (DV) is what you want to use the model to explain or predict. The values of
this variable depend on other variables.
 It’s also known as the response variable, outcome variable, and left-hand variable. Graphs place
dependent variables on the vertical, or Y, axis.
 a dependent variable is exactly what it sounds like. It is something that depends on other factors.
For example the blood sugar test depends on what food you ate, at which time you ate etc.
Unlike the independent variable, the dependent variable isn’t manipulated by the investigator. Instead, it
represents an outcome: the data produced by the experiment.
Confounding Variable
An uncontrolled variable that compromises the interpretation of a study is known as a confounding variable.
Sometimes a confounding variable occurs because it’s impossible to assign subjects randomly to different
conditions.'''

# %%
#12 b
import numpy as np
import pandas as pd
data = {
    'FRIENDS': ['400 above', '350-399', '300-349', '250-299', '200-249', '150-199', '100-149','50-99','0-49'],
    'f': [2, 5, 12, 17, 23, 49, 27, 29, 36]
}
df =pd.DataFrame(data)
#(i) What is the shape of this distribution?
#shape is 'Right Skewed'
#(ii) Find the relative frequencies
total_friends=df['f'].sum()
df['Relative Frequency']=df['f'];total_friends
print(df['Relative Frequency'])
#iii)Find the approximate percentile rank of the interval 300-349.
cumulative_frequency = np.cumsum(df['f'])
percentile_rank = (cumulative_frequency[2] - (df['f'][2] / 2)) / total_friends * 100
print(percentile_rank)
#iv) Convert to a histogram."""

import matplotlib.pyplot as plt

df['Midpoint'] = df['FRIENDS'].apply(lambda x: int(x.split('-')[0]) if '-' in x else 400)

plt.bar(df['Midpoint'], df['f'], width=30, edgecolor='black')
plt.xlabel('Number of Friends')
plt.ylabel('Frequency')
plt.title('Histogram of Number of Friends')
plt.show()
#(v) Why would it not be possible to convert to a stem and leaf display?"""
#It's not possible to convert to a stem and leaf display easily
# Out:
# 0     2
# 1     5
# 2    12
# 3    17
# 4    23
# 5    49
# 6    27
# 7    29
# 8    36
# Name: Relative Frequency, dtype: int64
# 6.5

# %%
'''13.a.i)Each of the following pairs represents the number of licensed drivers ( X ) and the number of cars ( Y ) for seven houses in my neighborhood: drivers
(X) Cars (Y)
5 4
5 3
2 2
2 2
3 2
1 1
2 2
(a) Construct a scatterplot to verify a lack of pronounced curvilinearity.
(b) Determine the least squares equation for these data. (Remember, you will first have to calculate r, SS y, and SS x.) Y 1 = bX+a
(c) Determine the standard error of estimate, s y | x, given that n = 7.
(d) Predict the number of cars for each of two new families with two and five drivers.
The sample statistic required in the question to answer each of the parts of the question are calculated using the excel shown in the below screenshot.
(a) The scatterplot of the given data can be shown as,
The above diagram shows that there is no curvilinearity build with the data.
(b) The slope coefficient can be calculated as,
The intercept coefficient can be calculated as,So, the least-squares equation can be written as
(c) The standard error of the estimate can be calculated as,
Therefore, the standard error of the estimate is 0.4019.
(d) The predicted number of cars for two drivers can be calculated as,
Similarly, the predicted number of cars for 5 drivers is 3.4808. Therefore, the predicted number of cars for each of two new families with two and five drivers are 2 and 4, respectively.'''
# Out:
# '13.a.i)Each of the following pairs represents the number of licensed drivers ( X ) and the number of cars ( Y ) for seven houses in my neighborhood: drivers\n(X) Cars (Y)\n5 4\n5 3\n2 2\n2 2\n3 2\n1 1\n2 2\n(a) Construct a scatterplot to verify a lack of pronounced curvilinearity.\n(b) Determine the least squares equation for these data. (Remember, you will first have to calculate r, SS y, and SS x.) Y 1 = bX+a\n(c) Determine the standard error of estimate, s y | x, given that n = 7.\n(d) Predict the number of cars for each of two new families with two and five drivers.\nThe sample statistic required in the question to answer each of the parts of the question are calculated using the excel shown in the below screenshot.\n(a) The scatterplot of the given data can be shown as,\nThe above diagram shows that there is no curvilinearity build with the data.\n(b) The slope coefficient can be calculated as,\nThe intercept coefficient can be calculated as,So, the least-squares equation can b
# ...

# %%
#13)a)
#ii)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

size = 100
x_linear = np.linspace(0, 10, size)
y_linear = 2 * x_linear + np.random.normal(0, 1, size)

x_quadratic = np.linspace(0, 10, size)
y_quadratic = 0.5 * (x_quadratic - 5) ** 2 + np.random.normal(0, 1, size)

x_random = np.random.rand(size) * 10
y_random = np.random.rand(size) * 10

data = pd.DataFrame({'Linear': y_linear, 'Quadratic': y_quadratic, 'Random': y_random})

plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.scatter(x_linear, y_linear, c='blue')
plt.title('Linear Relationship')

plt.subplot(2, 2, 2)
plt.scatter(x_quadratic, y_quadratic, c='green')
plt.title('Quadratic Relationship')

plt.subplot(2, 2, 3)
plt.scatter(x_random, y_random, c='red')
plt.title('Random Relationship')

plt.tight_layout()
plt.show()

# %%
 13)b)i)
In studies dating back over 100 years it's well established that regression towards the mean occurs between the height of the father and the height of the adult sons
Indicate whether the following statements are true or false
1)sons of tall father will tend to be shorter than their fathers
2)sons of short father tend to be taller than the mean for all sons
3)every son of a tall father will be shorter than his father
4)taken as a group, adult sons are shorter than their father
5)fathers of tall sons will tend to be taller than their sons
6)father of short sons will tend to be taller than their sons but shorter than the mean of all fathers
True
True
False
False
False
True

# %%
'''13.b)(ii) Interpret the value of r ^ 2 in correlation based analysis.
The coefficient of determination, \( r^2 \), in correlation-based analysis represents the proportion of the variance in the dependent variable (\( Y \)) that can be explained by the independent variable (\( X \)). It is calculated as the square of the correlation coefficient (\( r \)).

Here's an interpretation:

- \( r^2 \) is a measure of the goodness of fit of the regression model. It ranges from 0 to 1, where 0 indicates that the model does not explain any variance, and 1 indicates a perfect fit.

- A high \( r^2 \) (close to 1) suggests that a large proportion of the variability in the dependent variable is predictable from the independent variable. In other words, the model is doing a good job of explaining and predicting the observed outcomes.

- A low \( r^2 \) (closer to 0) indicates that the independent variable does not explain much of the variability in the dependent variable. The model may not be a good fit.

- \( r^2 \) is often expressed as a percentage, making it more intuitive. For example, an \( r^2 \) value of 0.80 can be interpreted as 80% of the variability in \( Y \) is explained by \( X \).

In summary, \( r^2 \) provides insight into how well the independent variable accounts for the observed variation in the dependent variable. It is a crucial metric in regression analysis for assessing the model's explanatory power.'''
# Out:
# "13.b)(ii) Interpret the value of r ^ 2 in correlation based analysis.\nThe coefficient of determination, \\( r^2 \\), in correlation-based analysis represents the proportion of the variance in the dependent variable (\\( Y \\)) that can be explained by the independent variable (\\( X \\)). It is calculated as the square of the correlation coefficient (\\( r \\)).\n\nHere's an interpretation:\n\n- \\( r^2 \\) is a measure of the goodness of fit of the regression model. It ranges from 0 to 1, where 0 indicates that the model does not explain any variance, and 1 indicates a perfect fit.\n  \n- A high \\( r^2 \\) (close to 1) suggests that a large proportion of the variability in the dependent variable is predictable from the independent variable. In other words, the model is doing a good job of explaining and predicting the observed outcomes.\n\n- A low \\( r^2 \\) (closer to 0) indicates that the independent variable does not explain much of the variability in the dependent variable. 
# ...

# %%
#14.b.Consider that, an E-Commerce organization like Amazon, have different regions sales as NorthSales, SouthSales, WestSales, EastSales.csv files. They want to combine North and West region sales and South and East sales to find the aggregate sales of these collaborating regions Help them to do so
'''using pandas, a powerful data manipulation library in Python, to accomplish this. Assuming you have CSV files named NorthSales.csv, SouthSales.csv, WestSales.csv, and EastSales.csv, here's a sample code to combine North and West sales as well as South and East sales:'''
import pandas as pd

# Load data from CSV files
north_sales = pd.read_csv('NorthSales.csv')
south_sales = pd.read_csv('SouthSales.csv')
west_sales = pd.read_csv('WestSales.csv')
east_sales = pd.read_csv('EastSales.csv')

# Combine North and West sales
north_west_sales = pd.concat([north_sales, west_sales])

# Combine South and East sales
south_east_sales = pd.concat([south_sales, east_sales])

# Aggregate sales for the collaborating regions
aggregate_north_west_sales = north_west_sales.groupby('ProductID')['Sales'].sum().reset_index()
aggregate_south_east_sales = south_east_sales.groupby('ProductID')['Sales'].sum().reset_index()

# Print or save the results as needed
print("Aggregate Sales for North and West Regions:")
print(aggregate_north_west_sales)

print("\nAggregate Sales for South and East Regions:")
print(aggregate_south_east_sales).
# Out:
#   File "<ipython-input-30-8e789f63b613>", line 26
#     print(aggregate_south_east_sales).
#                                       ^
# SyntaxError: invalid syntax

# %%
#15) a. How text and image annotations are done using  python? Give an  of your own with appropriate python code
#In Python, you can use the Matplotlib library for both text and image annotations in plots. Here's a brief explanation and an example for each:

### Text Annotation:

#**Explanation:**
#Text annotations are used to add labels or comments to specific points on a plot.

#**Python Code Example:**
import matplotlib.pyplot as plt

# Generate sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a simple plot
plt.plot(x, y, marker='o')

# Add text annotation
plt.annotate('Max Value', xy=(5, 10), xytext=(4, 9),
             arrowprops=dict(facecolor='red', shrink=0.05),
             fontsize=10, color='blue')

plt.title('Text Annotation Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

#This code creates a simple plot and adds a text annotation indicating the maximum value.

### Image Annotation:

#**Explanation:**
#Image annotations involve adding images to a plot, providing additional visual information.

#**Python Code Example:**
import matplotlib.pyplot as plt
import matplotlib.offsetbox as offsetbox
from matplotlib.patches import Ellipse

# Create a figure and axis
fig, ax = plt.subplots()

# Add an image annotation
arr_img = plt.imread('path/to/image.png')
imagebox = offsetbox.OffsetImage(arr_img, zoom=0.2)
ab = offsetbox.AnnotationBbox(imagebox, xy=(0.5, 0.5), xycoords='axes fraction', boxcoords="axes fraction", frameon=False)
ax.add_artist(ab)

# Add a shape annotation (ellipse)
ellipse = Ellipse(xy=(0.7, 0.7), width=0.2, height=0.1, edgecolor='red', fc='None', lw=2)
ax.add_patch(ellipse)

plt.title('Image Annotation Example')
plt.show()

#This code adds an image annotation and a red ellipse shape to the plot.

#Adjust the coordinates, text, image path, or other parameters as needed for your specific use case.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-6de0ee7fd3f2> in <cell line: 45>()
#      43
#      44 # Add an image annotation
# ---> 45 arr_img = plt.imread('path/to/image.png')
#      46 imagebox = offsetbox.OffsetImage(arr_img, zoom=0.2)
#      47 ab = offsetbox.AnnotationBbox(imagebox, xy=(0.5, 0.5), xycoords='axes fraction', boxcoords="axes fraction", frameon=False)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2193 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2194 def imread(fname, format=None):
# -> 2195     return matplotlib.image.imread(fname, format)
#    2196
#    2197
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imread(fname, format)
#    1561             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562             )
# ...

# %%
#15) b. How text and image annotations are done using  python? Give an  of your own with appropriate python code
#In Python, you can use the Matplotlib library for both text and image annotations in plots. Here's a brief explanation and an example for each:

### Text Annotation:

#**Explanation:**
#Text annotations are used to add labels or comments to specific points on a plot.

#**Python Code Example:**
#```python
import matplotlib.pyplot as plt

# Generate sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a simple plot
plt.plot(x, y, marker='o')

# Add text annotation
plt.annotate('Max Value', xy=(5, 10), xytext=(4, 9),
             arrowprops=dict(facecolor='red', shrink=0.05),
             fontsize=10, color='blue')

plt.title('Text Annotation Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

#This code creates a simple plot and adds a text annotation indicating the maximum value.

### Image Annotation:

#**Explanation:**
#Image annotations involve adding images to a plot, providing additional visual information.

#**Python Code Example:**
#```python
import matplotlib.pyplot as plt
import matplotlib.offsetbox as offsetbox
from matplotlib.patches import Ellipse

fig, ax = plt.subplots()

# Add an image annotation
arr_img = plt.imread('path/to/image.png')
imagebox = offsetbox.OffsetImage(arr_img, zoom=0.2)
ab = offsetbox.AnnotationBbox(imagebox, xy=(0.5, 0.5), xycoords='axes fraction', boxcoords="axes fraction", frameon=False)
ax.add_artist(ab)

# Add a shape annotation (ellipse)
ellipse = Ellipse(xy=(0.7, 0.7), width=0.2, height=0.1, edgecolor='red', fc='None', lw=2)
ax.add_patch(ellipse)

plt.title('Image Annotation Example')
plt.show()

#This code adds an image annotation and a red ellipse shape to the plot.

#Adjust the coordinates, text, image path, or other parameters as needed for your specific use case.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-df33748b5766> in <cell line: 46>()
#      44
#      45 # Add an image annotation
# ---> 46 arr_img = plt.imread('path/to/image.png')
#      47 imagebox = offsetbox.OffsetImage(arr_img, zoom=0.2)
#      48 ab = offsetbox.AnnotationBbox(imagebox, xy=(0.5, 0.5), xycoords='axes fraction', boxcoords="axes fraction", frameon=False)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2193 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2194 def imread(fname, format=None):
# -> 2195     return matplotlib.image.imread(fname, format)
#    2196
#    2197
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imread(fname, format)
#    1561             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562             )
# ...

# %%
#16.

#(a) Perform an exploratory data analysis for the following data with diffe types of plots: ent

The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.

Data attributes:-

Age of patient at the time of operation (numerical)

Patient's year of operation (year - 1900, numerical)

Number of positive axillary nodes detected (numerical)

Survival status (class attribute) 1 = the patient survived 5 years or longer, 2 = the patient died within 5 year'''
#Certainly! To perform exploratory data analysis (EDA) on the given dataset, you can use various plots to understand the distribution and relationships between different attributes. Assuming you have the data in a DataFrame named `df`, here's a sample Python code using the popular `seaborn` and `matplotlib` libraries:


import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with the dataset

# Pairplot for overall understanding of relationships
sns.pairplot(df, hue='Survival Status', vars=['Age', 'Year of Operation', 'Positive Nodes'])
plt.suptitle('Pairplot of Data Attributes', y=1.02)
plt.show()

# Boxplot to visualize the distribution of Age, Year of Operation, and Positive Nodes
plt.figure(figsize=(15, 8))
plt.subplot(2, 2, 1)
sns.boxplot(x='Survival Status', y='Age', data=df)
plt.title('Boxplot of Age')

plt.subplot(2, 2, 2)
sns.boxplot(x='Survival Status', y='Year of Operation', data=df)
plt.title('Boxplot of Year of Operation')

plt.subplot(2, 2, 3)
sns.boxplot(x='Survival Status', y='Positive Nodes', data=df)
plt.title('Boxplot of Positive Nodes')

plt.show()

# Violinplot to combine boxplot and KDE for a more detailed view
plt.figure(figsize=(15, 8))
plt.subplot(2, 2, 1)
sns.violinplot(x='Survival Status', y='Age', data=df)
plt.title('Violinplot of Age')

plt.subplot(2, 2, 2)
sns.violinplot(x='Survival Status', y='Year of Operation', data=df)
plt.title('Violinplot of Year of Operation')

plt.subplot(2, 2, 3)
sns.violinplot(x='Survival Status', y='Positive Nodes', data=df)
plt.title('Violinplot of Positive Nodes')

plt.show()


#This code generates pair plots, box plots, and violin plots to explore relationships and distributions in the given dataset. Adjustments may be needed based on your specific dataset and requirements. Ensure you have the necessary libraries installed by using `pip install seaborn matplotlib pandas`.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Survival Status'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#16.(b) Assume that an r of - 0.8 describes the strong negative relationship between years of heavy smoking (X) and life expectancy (Y).

'''Assume, furthermore, that the distributions of heavy smoking and life expectancy each have the following means and sums of squares: 5 60 35 70y X Y SS SS

(i) Determine the least squares regression equation for predicting life expectancy from years of heavy smoking.

(3)

(ii) Determine the standard error of estimate, Sy / x assuming that the correlation of -.80 was based on n = 50 pairs of observations. (3)

(iii) Supply a rough interpretation of Sy / x

(3)

(iv) Predict the life expectancy for John, who has smoked heavily for 8 years.

(3)

(v) Predict the life expectancy for Katie, who has never smoked heavily.

(3)'''
'''Certainly! Let's break down each part of the question:

**(i) Least Squares Regression Equation:**

Given a correlation coefficient (r) of -0.8, the slope (b) of the regression equation can be calculated using the formula:

\[ b = r \cdot \left( \frac{Sy}{Sx} \right) \]

where \(Sy\) is the standard deviation of \(Y\) and \(Sx\) is the standard deviation of \(X\).

The least squares regression equation is then given by:

\[ Y = a + b \cdot X \]

where \(a\) is the intercept. You can calculate \(a\) using:

\[ a = \bar{Y} - b \cdot \bar{X} \]

Now, plug in the provided means and sums of squares to find \(a\) and \(b\).

**(ii) Standard Error of Estimate \(S_{y|x}\):**

\[ S_{y|x} = \sqrt{(1 - r^2) \cdot SS_y} \]

where \(SS_y\) is the sum of squares of \(Y\).

**(iii) Rough Interpretation of \(S_{y|x}\):**

The standard error of estimate, \(S_{y|x}\), represents the typical distance between the observed values and the values predicted by the regression equation. It gives a measure of how well the regression equation predicts the dependent variable.

**(iv) Predict Life Expectancy for John (smoked heavily for 8 years):**

\[ \hat{Y} = a + b \cdot X \]

where \(X\) is the years of heavy smoking.

**(v) Predict Life Expectancy for Katie (never smoked heavily):**

For Katie, \(X = 0\) as she has never smoked heavily. Use the regression equation to predict \(Y\).

Please provide the means and sums of squares for \(X\) and \(Y\) so I can help you with the calculations.'''
# Out:
# "Certainly! Let's break down each part of the question:\n\n**(i) Least Squares Regression Equation:**\n\nGiven a correlation coefficient (r) of -0.8, the slope (b) of the regression equation can be calculated using the formula:\n\n\\[ b = r \\cdot \\left( \x0crac{Sy}{Sx} \right) \\]\n\nwhere \\(Sy\\) is the standard deviation of \\(Y\\) and \\(Sx\\) is the standard deviation of \\(X\\).\n\nThe least squares regression equation is then given by:\n\n\\[ Y = a + b \\cdot X \\]\n\nwhere \\(a\\) is the intercept. You can calculate \\(a\\) using:\n\n\\[ a = \x08ar{Y} - b \\cdot \x08ar{X} \\]\n\nNow, plug in the provided means and sums of squares to find \\(a\\) and \\(b\\).\n\n**(ii) Standard Error of Estimate \\(S_{y|x}\\):**\n\n\\[ S_{y|x} = \\sqrt{(1 - r^2) \\cdot SS_y} \\]\n\nwhere \\(SS_y\\) is the sum of squares of \\(Y\\).\n\n**(iii) Rough Interpretation of \\(S_{y|x}\\):**\n\nThe standard error of estimate, \\(S_{y|x}\\), represents the typical distance between the observed values 
# ...
